# %% [markdown]
# # Estruturas de decisão
#
# <span style="color: red;"><b>Todos os exercícios são feitos partindo-se do pressuposto de que todas as entradas são dadas de forma correta. Casos limite não mencionados no enunciado não são abordados porque não fazem parte do exercício.</b></span>

# %% [markdown]
# #### 1. Faça um Programa que peça dois números e imprima o maior deles.

# %%
numero1 = float(input("Digite um número:"))
numero2 = float(input('Digite um número'))

if numero1 > numero2:
    print(f'O maior número digitado foi: {numero1}')
else:
    print(f'O maior número digitado foi: {numero2}')
# Out:
# O maior número digitado foi: 8.0

# %% [markdown]
# #### 2. Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
numero_verificador = float(input("Digite um número:"))


if numero_verificador > 0:
    print(f'O maior número digitado foi: {numero_verificador}, ele é POSITIVO')
else:
    print(f'O maior número digitado foi: {numero_verificador}, ele é NEGATIVO')
# Out:
# O maior número digitado foi: -80, ele é NEGATIVO

# %% [markdown]
# #### 3. Faça um Programa que verifique o estado civil de uma pessoa. Se a letra digitada é "C" (Casado), "S" (Solteiro), "D" (Divorciado), "V" (Viúvo) ou "O" (outros). Conforme a letra escrita pelo usuário seu programa deve escrever o estado civil, exemplo:
#
# Usuário digita: C
#
# Seu programa deve responder:
# C - Casado

# %%
C = "Casado"
S = "Solteiro"
D = "Divorciado"
V = "Viuvo"
O = "Outros"

Estado_Civil = input("Qual seu estado Civil? C, S, D, V ou O").upper()

if Estado_Civil == 'C':
    print(f'Seu estado civil é {C}')
elif Estado_Civil == S:
    print(f'Seu estado civil é {S}')
elif Estado_Civil == D:
    print(f'Seu estado civil é {D}')
elif Estado_Civil == V:
    print(f'Seu estado civil é {V}')
elif Estado_Civil == O:
    print(f'Seu estado civil é {O}')
else:
    print(f'Digite apenas um das letras mencionadas: C, S, D, V ou O')
# Out:
# Seu estado civil é Casado

# %% [markdown]
# #### 4. Faça um Programa que verifique se o e-mail digitado faz parte dos e-mails de spam.

# %%
emails_spam = "fulano@gmail.com,beltrano@gmail.com,ciclano@gmail.com"

# %% [markdown]
# #### 5. Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
#
# ##### A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# ##### A mensagem "Reprovado", se a média for menor do que sete;
# ##### A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
nota1 = input('Qual nota da 1ª prova?').replace(',','.')
nota2 = input('Qual nota da 2ª prova?').replace(',','.')


nota1 = float(nota1)
nota2 = float(nota2)
media = (nota1 + nota2) / 2

if media >= 7.0 and media < 10.0:
    print(f"Parabéns, você foi aprovado com média {media}")
elif media == 10.0:
    print(f"Parabéns, você foi aprovado com distinção, pois sua média foi {media}")
else:
    print(F'Voce foi reprovado, sua média foi {media}, que é inferior ao minimo: 7,0')
# Out:
# Parabéns, você foi aprovado com distinção, pois sua média foi 10.0

# %% [markdown]
# #### 6. Faça um Programa que leia o orçamento de 3 empresas e mostre o maior deles.

# %%
orcamento1 = float(input('Qual valor do 1° orçamento?').replace(',','.'))
orcamento2 = float(input('Qual valor do 2° orçamento?').replace(',','.'))
orcamento3 = float(input('Qual valor do 3° orçamento?').replace(',','.'))

if orcamento1 > orcamento2 and orcamento1 > orcamento3:
    print(f'O orçamento 1, de valor R${orcamento1}, é o maior de todos')
elif orcamento2 > orcamento1 and orcamento2 > orcamento3:
    print(f'O orçamento 2, de valor R${orcamento2}, é o maior de todos')
else: print(f'O orçamento 3, de valor R${orcamento3}, é o maior de todos')
# Out:
# O orçamento 3, de valor R$50.2, é o maior de todos

# %% [markdown]
# #### 7. Faça um Programa que leia três orçamentos e mostre o maior e o menor deles.

# %%
menor_orcamento = min(orcamento1, orcamento2, orcamento3)

if menor_orcamento == orcamento1:
    print(f'O orçamento 1, de valor R${orcamento1}, é o maior de todos')
elif menor_orcamento == orcamento2:
    print(f'O orçamento 2, de valor R${orcamento2}, é o maior de todos')
else:
    print(f'O orçamento 3, de valor R${orcamento3}, é o maior de todos')
# Out:
# O orçamento 2, de valor R$3.2, é o maior de todos

# %% [markdown]
# #### 8. Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
#################################PRODUTO1#####################################
produto1 = input('Qual produto você quer comprar?')
preco1_1 = float(input('Qual valor do produto da 1ª opção?').replace(',','.'))
preco1_2 = float(input('Qual valor do produto da 2ª opção?').replace(',','.'))
preco1_3 = float(input('Qual valor do produto da 3ª opção?').replace(',','.'))
#################################PRODUTO2#####################################
produto2 = input('Qual produto você quer comprar?')
preco2_1 = float(input('Qual valor do produto da 1ª opção?').replace(',','.'))
preco2_2 = float(input('Qual valor do produto da 2ª opção?').replace(',','.'))
preco2_3 = float(input('Qual valor do produto da 3ª opção?').replace(',','.'))
#################################PRODUTO3#####################################
produto3 = input('Qual produto você quer comprar?')
preco3_1 = float(input('Qual valor do produto da 1ª opção?').replace(',','.'))
preco3_2 = float(input('Qual valor do produto da 2ª opção?').replace(',','.'))
preco3_3 = float(input('Qual valor do produto da 3ª opção?').replace(',','.'))

#################################FUNÇÕES######################################

menor_orcamento_prd1 = min(preco1_1, preco1_2, preco1_3)
menor_orcamento_prd2 = min(preco2_1, preco2_2, preco2_3)
menor_orcamento_prd3 = min(preco3_1, preco3_2, preco3_3)

################################VALIDADOR######################################

print(f"Para que você economize no {produto1}, é preciso comprar com valor de R${menor_orcamento_prd1}, pois é o mais barato.\n"
      f'Para que você economize no {produto2}, é preciso comprar com valor de R${menor_orcamento_prd2}, pois é o mais barato.\n'
      f'Para que você economize no {produto3}, é preciso comprar com valor de R${menor_orcamento_prd3}, pois é o mais barato.\n')
# Out:
# Para que você economize no Maionese, é preciso comprar com valor de R$3.27, pois é o mais barato.
# Para que você economize no Ração, é preciso comprar com valor de R$3.24, pois é o mais barato.
# Para que você economize no Suco de Laranja, é preciso comprar com valor de R$1.2, pois é o mais barato.

# %% [markdown]
# #### 9. Faça um Programa que leia três números e mostre-os em ordem decrescente.

# %%
numero_1 = float(input("Digite um número:").replace(',','.'))
numero_2 = float(input("Digite um número:").replace(',','.'))
numero_3 = float(input("Digite um número:").replace(',','.'))

if numero_1 > numero_2 and numero_1 > numero_3 and numero_2 > numero_3:
    print(f"Do maior para o menor: {numero_1},{numero_2} e {numero_3}")
elif numero1 > numero_2 and numero_1 > numero_3 and numero_2 < numero_3:
    print(f"Do maior para o menor: {numero_1},{numero_3} e {numero_2}")
elif numero_2 > numero_1 and numero_2 > numero_3 and numero_1 > numero_3:
    print(f"Do maior para o menor: {numero_2},{numero_1} e {numero_3}")
elif numero_2 > numero_1 and numero_2 > numero_3 and numero_1 < numero_3:
    print(f"Do maior para o menor: {numero_2},{numero_3} e {numero_1}") 
elif numero_3 > numero_1 and numero_3 > numero_2 and numero_1 > numero_2:
    print(f'Do maior para o menor: {numero_3},{numero_1} e {numero_2}')
else:
   print(f"Do maior para o menor: {numero_3},{numero_2} e {numero_1}")
# Out:
# Do maior para o menor: 6.0,5.0 e 4.0

# %% [markdown]
# #### 10. Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno. Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
M = "Matutino"
V = "Vespertino"
N = "Noturno"

Turno = input("Qual período você estuda?? M, V ou N").upper()

if Turno == 'M':
    print(f'Bom dia!')
elif Turno == 'V':
    print(f'Boa tarde!')
elif Turno == 'N':
    print(f'Boa noite!')
else:
    print(f'Valor invalido, por gentileza, digite corretamente "M, V ou N"')
# Out:
# Boa tarde!

# %% [markdown]
# #### 11. As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes. Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no salário atual:
#
# ##### salários até R\\$ 280,00 (incluindo) : aumento de 20%
#
# ##### salários entre R\\$ 280,00 e R\\$ 700,00 : aumento de 15%
#
# ##### salários entre R\\$ 700,00 e R\\$ 1500,00 : aumento de 10%
#
# ##### salários de R\\$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
#
# ###### o salário antes do reajuste;
#
# ###### o percentual de aumento aplicado;
#
# ###### o valor do aumento;
#
# ###### o novo salário, após o aumento.
#
# ###### Obs: Não vamos nos preocupar tanto com a formatação dos números (nº de casas decimais, por exemplo, veremos isso no próximo módulo)

# %%
salario = float(input("Qual o valor do seu salario atual").replace(',','.'))

if salario <= 280.00:
    novo_salario = (salario * 0.20) + salario
    percentual = '20%'
elif salario <=700.00:
    novo_salario = (salario * 0.15) + salario
    percentual = '15%'
elif salario <=1500.00:
    novo_salario = (salario * 0.10) + salario
    percentual = '10%'
else:
    novo_salario = (salario * 0.05) + salario
    percentual = '5%'
print(f'Seu salario era de R${salario}, ou seja, você teve um aumento de {percentual}. Com isso seu novo salario é de {novo_salario} ')
# Out:
# Seu salario era de R$3000.0, ou seja, você teve um aumento de 5%. Com isso seu novo salario é de 3150.0

# %% [markdown]
# #### 12 . Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.
#
# Desconto do IR:<br>
# Salário Bruto até 900 (inclusive) - isento<br>
# Salário Bruto até 1500 (inclusive) - desconto de 5%<br>
# Salário Bruto até 2500 (inclusive) - desconto de 10%<br>
# Salário Bruto acima de 2500 - desconto de 20%<br>
# Imprima na tela as informações, dispostas conforme o exemplo abaixo. No exemplo o valor da hora é 5 e a quantidade de hora é 220.
#
# Salário Bruto: (5 * 220)        : R\\$ 1100,00<br>
# (-) IR (5%)                     : R\\$   55,00<br>
# (-) INSS ( 10%)                 : R\\$  110,00<br>
# FGTS (11%)                      : R\\$  121,00<br>
# Total de descontos              : R\\$  165,00<br>
# Salário Liquido                 : R\\$  935,00<br>
#
# ###### Obs: Não vamos nos preocupar tanto com a formatação dos números (nº de casas decimais, por exemplo, veremos isso no próximo módulo)

# %%
horas_trabalhadas = int(input('Quantas horas vocês trabalhou?'))
valor_hora = float(input('Qual o valor da sua hora de trabalho?').replace(',','.'))
salario_bruto = valor_hora * horas_trabalhadas
desconto_inss = salario_bruto * 0.10
fgts = salario_bruto * 0.11
if salario_bruto <= 900.00:
    desconto_ir = 0.00
elif salario_bruto > 900.00 and salario_bruto < 1500.00:
    desconto_ir = salario_bruto * 0.05
elif salario_bruto >= 1500.00 and salario_bruto < 2500.00:
    desconto_ir = salario_bruto * 0.10
else:
    desconto_ir = salario_bruto * 0.20
descontos = desconto_inss + desconto_ir
salario = salario_bruto - descontos

print(f'O Salario bruto desse mês é de: R${salario_bruto}, com desconto de INSS: R${desconto_inss} e de IR: R${desconto_ir}. Seu FGTS do mês foi de: R${fgts}\n'
      f'Somando os descontos deu: R${descontos}, ou seja, seu salario liquido é de: R${salario}')
# Out:
# 1100.0
# 55.0
# O Salario bruto desse mês é de: R$1100.0, com desconto de INSS: R$110.0 e de IR: R$55.0. Seu FGTS do mês foi de: R$121.0
# Somando os descontos deu: R$165.0, ou seja, seu salario liquido é de: R$935.0

# %% [markdown]
# #### 13. Faça um Programa que leia um número e exiba o dia correspondente da semana. (1-Domingo, 2- Segunda, etc.), se digitar outro valor deve aparecer valor inválido.

# %%
dia = int(input('Informe o número entre 1 e 7:'))

if dia == 1:
    dia_semana = 'Domingo'
elif dia == 2:
    dia_semana = 'Segunda-feira'
elif dia == 3:
    dia_semana = 'Terça-feira'
elif dia == 4:
    dia_semana = 'Quarta-feira'
elif dia == 5:
    dia_semana = 'Quinta-feira'
elif dia == 6:
    dia_semana = 'Sexta-feira'
elif dia == 7:
    dia_semana = 'Sábado'
else:
    print(f'Valor invalido, digite entre 1 e 7')
    
print(f'Hoje é {dia_semana}')
# Out:
# Hoje é Terça-feira

# %% [markdown]
# #### 14. Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule a sua média. Em seguida, mostre qual conceito o aluno teve. A atribuição de conceitos obedece à tabela abaixo:
# <pre>
# Média de Aproveitamento  Conceito
# Entre 9.0 e 10.0        A
# Entre 7.5 e 9.0         B
# Entre 6.0 e 7.5         C
# Entre 4.0 e 6.0         D
# Entre 4.0 e zero        E
# </pre>

# %%
nota1 = float(input('Qual a 1ª nota?').replace(',','.'))
nota2 = float(input('Qual a 2ª nota?').replace(',','.'))
media = (nota1 + nota2) / 2

if media <= 4:
    print(f'Sua méida foi {media}, seu conceito é E')
elif media <=6:
    print(f'Sua méida foi {media}, seu conceito é D')
elif media <=7.5:
    print(f'Sua méida foi {media}, seu conceito é C')
elif media <=9:
    print(f'Sua méida foi {media}, seu conceito é B')
else:
    print(f'Sua méida foi {media}, seu conceito é A')
# Out:
# Sua méida foi 8.0, seu conceito é B

# %% [markdown]
# #### 15. Você está construindo um calendário para controlar dias de trabalho a pedido do RH. Nessa construção, você vai precisar definir quais anos são bissextos e quais não são, para montar o calendário de forma correta. Faça um Programa que peça um número correspondente a um determinado ano e em seguida informe se este ano é ou não bissexto.
# <pre>
# Dica para determinar se um ano é bissexto:
# - São bissextos todos os anos múltiplos de 400, p.ex.: 1600, 2000, 2400, 2800...
# - São bissextos todos os múltiplos de 4, exceto se for múltiplo de 100 mas não de 400,
# p.ex.: 1996, 2000, 2004, 2008, 2012, 2016, 2020, 2024, 2028...
# - Não são bissextos todos os demais anos.<br>
# ex1: 2004 é múltiplo de 4, mas não é múltiplo de 100, então é bissexto.
# ex2: 2000 é múltiplo de 4, mas é múltiplo de 100, só que também é multiplo de 400, então é bissexto (porque todo ano múltiplo de 400 é bissexto, independente do resto).
# ex3: 1900 é múltiplo de 4, é múltiplo de 100, mas não é múltiplo de 400, então não é bissexto
#
# </pre>
#
# Dica: lembre que: numero % 4 é o resto da divisão do número por 4, ex: 10 % 3 = 1 (já que 10/3 = 3 e resta 1)

# %%
ano = int(input('Informe o ano: '))

if (ano % 4 == 0 and ano % 100 != 0) or ano % 400 ==0:
    print('Ano bissexto')
else: print ('Não é bissexto')
# Out:
# Ano bissexto

# %% [markdown]
# #### 16. Faça um Programa para leitura de três notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e presentar:
# <pre>
# A mensagem "Aprovado", se a média for maior ou igual a 7, com a respectiva média alcançada;
# A mensagem "Reprovado", se a média for menor do que 7, com a respectiva média alcançada;
# A mensagem "Aprovado com Distinção", se a média for igual a 10.
# </pre>

# %%
nota_1 = float(input('Nota 1').replace(',','.'))
nota_2 = float(input('Nota 2').replace(',','.'))
nota_3 = float(input('Nota 3').replace(',','.'))
media = round((nota_1 + nota_2 + nota_3)/3,2)

if media == 10:
    print(f'Parabéns, sua média foi: {media}, ou seja, você foi APROVADO COM DISTINÇÃO')
elif media >=7:
    print(f'Parabéns, sua média foi: {media}, ou seja, você foi APROVADO')
else:
    print(f'Sua méida foi: {media}, ou seja, você foi REPROVADO')
# Out:
# Sua méida foi: 5.0, ou seja, você foi REPROVADO

# %% [markdown]
# #### 17. João Papo-de-Pescador, homem de bem, comprou um microcomputador para controlar o rendimento diário de seu trabalho. Toda vez que ele traz um peso de peixes maior que o estabelecido pelo regulamento de pesca do estado de São Paulo (50 quilos) deve pagar uma multa de R$ 4,00 por quilo excedente. João precisa que você faça um programa que leia a variável peso (peso de peixes) e calcule o excesso. Gravar na variável excesso a quantidade de quilos além do limite e na variável multa o valor da multa que João deverá pagar. Imprima os dados do programa com as mensagens adequadas.

# %%
peso_limite = 50
valor_pelo_extra = 4.00
peso_ttl_pesca = float(input('Quantos quilos foram pescados hoje?').replace(',','.'))

if peso_ttl_pesca > peso_limite:
    excesso = round(peso_ttl_pesca - peso_limite,2)
    pagar = round(excesso * valor_pelo_extra,2)
    print(f'Você deverá pagar: R${pagar}, pois foram pescados em excesso {excesso}kg')
else:
    print(f'Hoje não foi excedido a quantidade de pesca')
# Out:
# Você deverá pagar: R$142.0, pois foram pescados em excesso 35.5kg

# %% [markdown]
# #### 18. Faça um Programa para um caixa eletrônico. O programa deverá perguntar ao usuário a valor do saque e depois informar quantas notas de cada valor serão fornecidas. As notas disponíveis serão as de 1, 5, 10, 50 e 100 reais. O valor mínimo é de 10 reais e o máximo de 600 reais. O programa não deve se preocupar com a quantidade de notas existentes na máquina.
# <pre>
# Exemplo 1: Para sacar a quantia de 256 reais, o programa fornece duas notas de 100, uma nota de 50, uma nota de 5 e uma nota de 1;
# Exemplo 2: Para sacar a quantia de 399 reais, o programa fornece três notas de 100, uma nota de 50, quatro notas de 10, uma nota de 5 e quatro notas de 1.
# </pre>
#
# Dica1: numero // 10 vai te dar como resposta a parte inteira da divisão do número por 10.<br>
# Dica2: numero % 10 vai te dar o resto da divisão do número por 10.

# %%
sacar = int(input('Qual valor deseja sacar?'))

n100 = 0
n50 = 0
n10 = 0
n5 = 0
n1 = 0

if 10 <= sacar <= 600:
    print('São necessárias:')
    if sacar >= 100:
        n100 = sacar // 100
        print(n100, 'notas de 100')
    if sacar % 100 >= 50:
        n50 = (sacar - 100*n100) // 50
        print(n50, 'notas de 50')
    if sacar % 50 >= 10:
        n10 = (sacar - 100*n100 - 50*n50) // 10
        print(n10, 'notas de 10')
    if sacar % 10 >= 5:
        n5 = (sacar - 100*n100 - 50*n50 - 10*n10) // 5
        print(n5, 'notas de 5')
    if sacar % 5 >= 1:
        n1 = sacar - 100*n100 - 50*n50 - 10*n10 - 5*n5
        print(n1, 'notas de 1')
else:
    print('Informe um valor entre 10 e 600 reais')
# Out:
# São necessárias:
# 1 notas de 50
# 2 notas de 10
# 1 notas de 5

# %% [markdown]
# #### 19. Faça um programa que faça 5 perguntas para uma pessoa sobre um crime. As perguntas são:
# <pre>
# "Telefonou para a vítima?"
# "Esteve no local do crime?"
# "Mora perto da vítima?"
# "Devia para a vítima?"
# "Já trabalhou com a vítima?"
# O programa deve no final emitir uma classificação sobre a participação da pessoa no crime. Se a pessoa responder positivamente a 2 questões ela deve ser classificada como "Suspeita", entre 3 e 4 como "Cúmplice" e 5 como "Assassino". Caso contrário, ele será classificado como "Inocente".
# </pre>

# %%
######JOGO#DO#DETETIVE######
Suspeito = 2
Cumplice = 3 or 4
Assasino = 5

####PERGUNTAS####
Q1 = input('Você ligou para vitima? S ou N').upper()
Q2 = input('Esteve no local do crime? S ou N').upper()
Q3 = input('Mora perto da vítima? S ou N').upper()
Q4 = input('Devia para a vítima? S ou N').upper()
Q5 = input('Já trabalhou com a vítima? S ou N').upper()   

####LOGICA####

if Q1 == "S":
    P1 = 1
else:
    P1 = 0
if Q2 == "S":
    P2 = 1
else:
    P2 = 0
if Q3 == "S":
    P3 = 1
else:
    P3 = 0
if Q4 == "S":
    P4 = 1
else:
    P4 = 0
if Q5 == "S":
    P5 = 1
else:
    P5 = 0

Resultado = P1+P2+P3+P4+P5

if Resultado < 2:
    print('Você é inocente')
elif Resultado == 2:
    print("Você é suspeito")
elif Resultado == 3 or Resultado == 4:
    print ("Você é cumplice")
else:
    print('Você é o assasino')
# Out:
# Você é cumplice

# %% [markdown]
# #### 20. Um posto está vendendo combustíveis com a seguinte tabela de descontos:
# <pre>
# Álcool:
# até 20 litros, desconto de 3% por litro
# acima de 20 litros, desconto de 5% por litro
# Gasolina:
# até 20 litros, desconto de 4% por litro
# acima de 20 litros, desconto de 6% por litro
#
# Escreva um algoritmo que leia o número de litros vendidos, o tipo de combustível (codificado da seguinte forma: A-álcool, G-gasolina), calcule e imprima o valor a ser pago pelo cliente sabendo-se que o preço do litro da gasolina é R$ 2,50 o preço do litro do álcool é R$ 1,90.
# </pre>

# %%
A = 1.90
G = 2.50

Pergunta1 = input('Qual combustivel vai querer? Alcool ou Gasolina?').lower()
if Pergunta1 == 'alcool':
    combustivel = 'A'
    Pergunta2 = float(input('Quantos litros irá abaster?').replace(',','.'))
    if Pergunta2 <20:
            desconto = 0.03
    else:
            desconto = 0.05
    Valor_a_pagar = round((Pergunta2 * A) - (Pergunta2 * desconto),2)
    print(f'Item: Alcool \n'
          f'Valor: R${A} \n'
          f'Litros abastecidos:{Pergunta2}\n'
          f'Desconto: R${desconto}\n'
          f'Valor a pagar: R${Valor_a_pagar}')
else:
    combustivel = 'G'
    Pergunta2 = float(input('Quantos litros irá abaster?').replace(',','.'))
    if Pergunta2 <20:
        desconto = 0.04
    else:
        desconto = 0.06
    Valor_a_pagar = round((Pergunta2 * G) - (Pergunta2 * desconto),2)
    print(f'Item: Gasolina \n'
          f'Valor: R${G} \n'
          f'Litros abastecidos:{Pergunta2}\n'
          f'Desconto: R${desconto}\n'
          f'Valor a pagar: R${Valor_a_pagar}')
# Out:
# Item: Gasolina
# Valor: R$2.5
# Litros abastecidos:20.0
# Desconto: R$0.06
# Valor a pagar: R$48.8

# %% [markdown]
# #### 21. Uma fruteira está vendendo frutas com a seguinte tabela de preços:
# <pre>
#                       Até 5 Kg           Acima de 5 Kg
# Morango         R$ 2,50 por Kg          R$ 2,20 por Kg
# Maçã            R$ 1,80 por Kg          R$ 1,50 por Kg
# Se o cliente comprar mais de 8 Kg em frutas ou o valor total da compra ultrapassar R$ 25,00, receberá ainda um desconto de 10% sobre este total. Escreva um algoritmo para ler a quantidade (em Kg) de morangos e a quantidade (em Kg) de maças adquiridas e escreva o valor a ser pago pelo cliente.
# </pre>

# %%
Morango = float(input('Quantos quilos de morango, você deseja?').replace(',','.'))
Maca = float(input('Quantos quilos de maçã, você deseja?').replace(',','.'))

if Morango < 5.00:
    Valor_Morango = Morango * 2.50
else:
    Valor_Morango = Morango * 2.20

if Maca < 5.00:
    Valor_Maca = Maca * 1.80
else:
    Valor_Maca = Maca * 1.50

Valor_real = Valor_Morango + Valor_Maca 

if Morango + Maca >= 8 or Valor_Morango + Valor_Maca >=25:
    Descontado = Valor_real  * 0.10
    Valor_Descontado = Valor_real - Descontado
    print(f'Você esta levando {Morango}Kgs de Morango e {Maca}Kgs de Maçã. No valor total de R${Valor_Descontado}')
else:
    print(f'Você esta levando {Morango}Kgs de Morango e {Maca}Kgs de Maçã. No valor total de R${Valor_real}')
# Out:
# Você esta levando 10.0Kgs de Morango e 0.0Kgs de Maçã. No valor total de R$19.8

# %% [markdown]
# #### 22. O Hipermercado Tabajara está com uma promoção de carnes que é imperdível. Confira:
# <pre>
#                       Até 5 Kg           Acima de 5 Kg
# File Duplo      R$ 4,90 por Kg          R$ 5,80 por Kg
# Alcatra         R$ 5,90 por Kg          R$ 6,80 por Kg
# Picanha         R$ 6,90 por Kg          R$ 7,80 por Kg
# Para atender a todos os clientes, cada cliente poderá levar apenas um dos tipos de carne da promoção, porém não há limites para a quantidade de carne por cliente. Se compra for feita no cartão Tabajara o cliente receberá ainda um desconto de 5% sobre o total da compra. Escreva um programa que peça o tipo e a quantidade de carne comprada pelo usuário e gere um cupom fiscal, contendo as informações da compra: tipo e quantidade de carne, preço total, tipo de pagamento, valor do desconto e valor a pagar.
# </pre>

# %%
File = float(input('Quantos quilos de Filé, você deseja?').replace(',','.'))
Alcatra = float(input('Quantos quilos de Alcatra, você deseja?').replace(',','.'))
Picanha = float(input('Quantos quilos de Picanha, você deseja?').replace(',','.'))


if File < 5.00:
    Valor_File = File * 4.90
else:
    Valor_File = File * 5.80

if Alcatra < 5.00:
    Valor_Alcatra = Alcatra * 5.90
else:
    Valor_Alcatra = Alcatra * 6.80

if Picanha < 5.00:
    Valor_Picanha = Picanha * 6.90
else:
    Valor_Picanha = Picanha * 7.80



Valor_real = Valor_File + Valor_Alcatra + Valor_Picanha

Kgs_carne = File+Alcatra+Picanha

Forma_pagamento = input('Qual a fomra de pagamento? CTB "Cartão Tabajara" ou Outro?').lower()
if Forma_pagamento == 'ctb':
    desconto = Valor_real * 0.05
    pagar_descontado = Valor_real - desconto
    print(f'Você esta levando {Kgs_carne}Kgs de carne. Total de R${Valor_real},\n'
          f'Com desconto de 5%, fica R${pagar_descontado}, pois esta usando Cartões Tabajara\n'
          f'Sendo File: {File} Kg -    R${Valor_File}\n'
          f'Sendo Alcatra: {Alcatra} Kg - R${Valor_Alcatra}\n'
          f'Sendo Alcatra: {Picanha} Kg - R${Valor_Picanha}\n')
else:
   print (f'Você esta levando {Kgs_carne}Kgs de carne. No valor total de R${Valor_real}\n'
          f'Sendo File: {File} Kg -     R${Valor_File}\n'
          f'Sendo Alcatra: {Alcatra} Kg - R${Valor_Alcatra}\n'
          f'Sendo Alcatra: {Picanha} Kg - R${Valor_Picanha}\n')
# Out:
# Você esta levando 61.25Kgs de carne. No valor total de R$436.5
# Sendo File: 10.0 Kg -       R$58.0
# Sendo Alcatra: 21.25 Kg - R$144.5
# Sendo Alcatra: 30.0 Kg - R$234.0

# %% [markdown]
# #### 23. Faça um Programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 6 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\\$ 80,00 ou em galões de 3,6 litros, que custam R\\$ 25,00.

# %%
area = float(input('Informe o tamanho da área a ser pintada em m²: '))
L_tintas = area / 6

# %% [markdown]
# ##### Informe ao usuário as quantidades de tinta a serem compradas e os respectivos preços em 3 situações.
#
# Dica: lembre dos operadores // e % mostrados em exercícios anteriores<br>
# Dica1: numero // 10 vai te dar como resposta a parte inteira da divisão do número por 10.<br>
# Dica2: numero % 10 vai te dar o resto da divisão do número por 10.
#
# ##### 1. Comprar apenas latas de 18 litros: (apenas latas inteiras)

# %%
if L_tintas % 18 > 0:
    lata = L_tintas //18+1
else:
    lata = L_tintas // 18

valor = lata * 80
print(f'Será preciso comprar {lata} latas, o custo será de R${valor}')
# Out:
# Será preciso comprar 2.0 latas, o custo será de R$160.0

# %% [markdown]
# ##### 2. Comprar apenas galões de 3,6 litros: (apenas galoes inteiros)

# %%
if L_tintas % 3.6 > 0:
    gl = L_tintas // 3.6+1
else:
    gl - L_tintas //3.6

valor = gl *25

print(f'Será preciso comprar {gl} galões de tinta, o custo será de R${valor}')
# Out:
# Será preciso comprar 7.0 galões de tinta, o custo será de R$175.0

# %% [markdown]
# ##### 3. Misturar latas e galões, de forma que o desperdício de tinta seja menor. Acrescente 10% de folga e sempre arredonde os valores para cima, isto é, considere latas cheias.

# %% [markdown]
# O custo da lata é 80/18 = 4,44 R\\$/L
#
# O custo do galão é 25/3,6 = 6,94 R\\$/L
#
# A lata é mais econômica, então todas as latas inteiras que pudermos usar devemos comprar em latas. Se ficar faltando alguma coisa para completar devemos avaliar se é melhor comprar latas ou galões. Exemplo:
#
# Se queremos comprar 90 litros. 5 latas dão exatamente 90 litros. Então devemos comprar tudo em latas.
#
# Se queremos comprar 95 litros. 5 latas dão exatamente 90 litros. Então devemos comprar pelo menos 5 latas e avaliar o que falta, se estes últimos 5 litros valem mais apenas em latas ou galões.
#
# Para os 5 litros faltantes precisamos de 2 galões que custam 50 reais no total. Ou de uma lata que custa 80 reais no total. Portanto, neste caso vale mais a pena usar 2 galões.
#
# Se queremos comprar 107 litros. 5 latas dão exatamente 90 litros. Então devemos comprar pelo menos 5 latas e avaliar o que falta, se estes últimos 5 litros valem mais apenas em latas ou galões.
#
# Para os 17 litros faltantes precisamos de 5 galões que custam 125 reais no total. Ou de uma lata que custa 80 reais no total. Portanto, neste caso vale mais a pena usar uma lata.
#
# 3 galões custam 75 reais, 4 galões custam 100 reais. Então, se for possível completar com até 3 galões escolhe-se galões. Qualquer quantidade maior que 3 galões, usa-se latas.
#
# Podemos ir ao exercício:

# %%
l_pra_folga = L_tintas * 1.1
gl = 0

lata = l_pra_folga // 18

falta_tinta = l_pra_folga - 18 * lata

if falta_tinta > 0:
    if falta_tinta % 3.6 > 0:
        falta_gl = falta_tinta // 3.6 +1
    else:
        falta_gl = falta_tinta // 3.6
    if falta_gl <=3:
        gl = falta_gl
    else:
        gl = 0
        lata = lata + 1

valor = lata * 80 + gl * 25

print(f'Será necessario {lata} latas e {gl} galões. O valor total será de R${valor}')
# Out:
# Será necessario 1.0 latas e 3.0 galões. O valor total será de R$155.0
